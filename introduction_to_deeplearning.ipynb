# %% [markdown]
# <a href="https://colab.research.google.com/github/oktaviacitra/ai-course-in-graduate-school/blob/main/introduction_to_deeplearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Generate data from -20, -19.75, -19.5, .... , 20
train_x = np.arange(-20, 20, 0.25)

# Calculate Target : sqrt(2x^2 + 1)
train_y = np.sqrt((2*train_x**2)+1)

# %%
import tensorflow as tf
from keras.models import Model, Sequential
from keras.layers import Input, Activation, Dense
from keras.optimizers import SGD

inputs = Input(shape=(1,))
h_layer = Dense(8, activation='relu')(inputs)
h_layer = Dense(4, activation='relu')(h_layer)
outputs = Dense(1, activation='linear')(h_layer)
model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer=SGD(lr=0.001), loss='mse')
model.fit(train_x, train_y, batch_size=20, epochs=10000, verbose=1)
model.save_weights('weights.h5')
# Out:
# Epoch 1/10000
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4654e-04
# Epoch 7502/10000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4834e-04
# Epoch 7503/10000
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4532e-04
# Epoch 7504/10000
# 8/8 [==============================] - 0s 2ms/step - loss: 5.5149e-04
# Epoch 7505/10000
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4770e-04
# Epoch 7506/10000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.5158e-04
# Epoch 7507/10000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4487e-04
# Epoch 7508/10000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4934e-04
# ...

# %%
predict_y = model.predict(train_x)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
import matplotlib.pylab as plt

plt.plot(train_x, train_y, 'r')
plt.plot(train_x, predict_y, 'b')
plt.show()

# %% [markdown]
# [source](https://medium.com/@samuelsena/pengenalan-deep-learning-part-4-deep-learning-framework-introduction-tensorflow-keras-b8f00b146f06)
